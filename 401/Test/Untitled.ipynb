# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import sph_harm, genlaguerre
import matplotlib.cm as cm

# %%
def hydrogen_wavefunction(n, l, m, r, theta, phi):
    R_nl = np.sqrt((2/(n*a))**3 * np.math.factorial(abs(n-l-1))/(2*n*np.math.factorial(abs(n+l))**3)) * np.exp(-r/(n*a)) * (2*r/(n*a))**l * genlaguerre(n-l-1, 2*l+1)(2*r/(n*a))
    Y_lm = sph_harm(m, l, phi, theta)
    return R_nl * Y_lm

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.special import sph_harm, genlaguerre
import matplotlib.cm as cm

def hydrogen_wavefunction(n, l, m, r, theta, phi):
    R_nl = abs(np.sqrt(abs((2/(n*a))**3 * np.math.factorial(abs(n-l-1))/(2*n*np.math.factorial(abs(n+l))**3)) * np.exp(-r/(n*a)) * (2*r/(n*a))**l * genlaguerre(n-l-1, 2*l+1)(2*r/(n*a))))
    Y_lm = sph_harm(m, l, phi, theta)
    return R_nl * Y_lm

a = 1  # Bohr radius
n_max = 4  # maximum principal quantum number to plot
l_max = n_max - 1  # maximum angular momentum quantum number to plot

fig = plt.figure(figsize=(12, 12))
for n in range(1, n_max+1):
    for l in range(0, min(n, l_max)+1):
        for m in range(-l, l+1):
            ax = fig.add_subplot(n_max, n_max, (n-1)*n_max+l+1, projection='3d')
            r = np.linspace(0, 40, 200)
            theta = np.linspace(0, np.pi, 100)
            phi = np.linspace(0, 2*np.pi, 200)
            R, THETA, PHI = np.meshgrid(r, theta, phi)
            X = R * np.sin(THETA) * np.cos(PHI)
            Y = R * np.sin(THETA) * np.sin(PHI)
            Z = R * np.cos(THETA)
            WAVEFUNCTION = hydrogen_wavefunction(n, l, m, R, THETA, PHI).real  # only use the real part of the wavefunction
            ax.set_title(f'n={n}, l={l}, m={m}')
            # ax.plot_surface(X, Y, Z, cmap='jet', rstride=1, cstride=1, facecolors=cm.jet(WAVEFUNCTION/WAVEFUNCTION.max()))
            ax.set_axis_off()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 28
#      26 Y = R * np.sin(THETA) * np.sin(PHI)
#      27 Z = R * np.cos(THETA)
# ---> 28 WAVEFUNCTION = hydrogen_wavefunction(n, l, m, R, THETA, PHI).real  # only use the real part of the wavefunction
#      29 ax.set_title(f'n={n}, l={l}, m={m}')
#      30 # ax.plot_surface(X, Y, Z, cmap='jet', rstride=1, cstride=1, facecolors=cm.jet(WAVEFUNCTION/WAVEFUNCTION.max()))
#
# Cell In[11], line 8, in hydrogen_wavefunction(n, l, m, r, theta, phi)
#       7 def hydrogen_wavefunction(n, l, m, r, theta, phi):
# ----> 8     R_nl = abs(np.sqrt(abs((2/(n*a))**3 * np.math.factorial(abs(n-l-1))/(2*n*np.math.factorial(abs(n+l))**3)) * np.exp(-r/(n*a)) * (2*r/(n*a))**l * genlaguerre(n-l-1, 2*l+1)(2*r/(n*a))))
#       9     Y_lm = sph_harm(m, l, phi, theta)
#      10     return R_nl * Y_lm
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.special import sph_harm, genlaguerre
import matplotlib.cm as cm

def hydrogen_wavefunction(n, l, m, r, theta, phi):
    R_nl = np.sqrt((2/(n*a))**3 * np.math.factorial(n-l-1)/(2*n*np.math.factorial(n+l)**3)) * np.exp(-r/(n*a)) * (2*r/(n*a))**l * genlaguerre(n-l-1, 2*l+1)(2*r/(n*a))
    Y_lm = sph_harm(m, l, phi, theta)
    return R_nl * Y_lm

a = 1  # Bohr radius
n_max = 4  # maximum principal quantum number to plot
l_max = n_max - 1  # maximum angular momentum quantum number to plot

fig = plt.figure(figsize=(12, 12))
for n in range(1, n_max+1):
    for l in range(0, min(n, l_max)+1):
        for m in range(-l, l+1):
            ax = fig.add_subplot(n_max, n_max, (n-1)*n_max+l+1, projection='3d')
            r = np.linspace(0, 40, 200)
            theta = np.linspace(0, np.pi, 100)
            phi = np.linspace(0, 2*np.pi, 200)
            R, THETA, PHI = np.meshgrid(r, theta, phi)
            X = R * np.sin(THETA) * np.cos(PHI)
            Y = R * np.sin(THETA) * np.sin(PHI)
            Z = hydrogen_wavefunction(n, l, m, R, THETA, PHI).real  # only use the real part of the wavefunction
            ax.set_title(f'n={n}, l={l}, m={m}')
            ax.plot_surface(X, Y, Z, cmap='jet', rstride=1, cstride=1, linewidth=0)
            ax.set_axis_off()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 17>()
#      27             Z = hydrogen_wavefunction(n, l, m, R, THETA, PHI).real  # only use the real part of the wavefunction
#      28             ax.set_title(f'n={n}, l={l}, m={m}')
# ---> 29             ax.plot_surface(X, Y, Z, cmap='jet', rstride=1, cstride=1, linewidth=0)
#      30             ax.set_axis_off()
#      32 plt.show()
#
# File ~\Documents\WPy64-39100\python-3.9.10.amd64\lib\site-packages\matplotlib\_api\deprecation.py:431, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     421     deprecation_addendum = (
#     422         f"If any parameter follows {name!r}, they should be passed as "
#     423         f"keyword, not positionally.")
#     424     warn_deprecated(
#     425         since,
#     426         name=repr(name),
#    (...)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.special import sph_harm, genlaguerre
import matplotlib.cm as cm
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 85

# %%
def hydrogen_wavefunction(n, l, m, r, theta, phi):
    R_nl = np.sqrt((2/(n*a))**3 * np.math.factorial(n-l-1)/(2*n*np.math.factorial(n+l)**3)) * np.exp(-r/(n*a)) * (2*r/(n*a))**l * genlaguerre(n-l-1, 2*l+1)(2*r/(n*a))
    Y_lm = sph_harm(m, l, phi, theta)
    return R_nl * Y_lm

# %%
a = 1  # Bohr radius
n_max = 2  # maximum principal quantum number to plot
l_max = n_max - 1  # maximum angular momentum quantum number to plot

fig = plt.figure(figsize=(12, 12))
for n in range(1, n_max+1):
    for l in range(0, min(n, l_max)+1):
        for m in range(-l, l+1):
            ax = fig.add_subplot(n_max, n_max, (n-1)*n_max+l+1, projection='3d')
            r = np.linspace(0, 40, 200)
            theta = np.linspace(0, np.pi, 100)
            phi = np.linspace(0, 2*np.pi, 200)
            R, THETA, PHI = np.meshgrid(r, theta, phi)
            X = R * np.sin(THETA) * np.cos(PHI)
            Y = R * np.sin(THETA) * np.sin(PHI)
            Z = np.zeros((len(r), len(theta)))
            for i in range(len(r)):
                for j in range(len(theta)):
                    Z[i, j] = hydrogen_wavefunction(n, l, m, R[i, j], THETA[i, j], PHI[i, j]).real
            ax.set_title(f'n={n}, l={l}, m={m}')
            ax.plot_surface(X, Y, Z, cmap='jet', rstride=1, cstride=1, linewidth=1)
            ax.set_axis_off()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.special import sph_harm, genlaguerre
import matplotlib.cm as cm



a = 1  # Bohr radius
n_max = 2  # maximum principal quantum number to plot
l_max = n_max - 1  # maximum angular momentum quantum number to plot

fig = plt.figure(figsize=(12, 12))
for n in range(1, n_max+1):
    for l in range(0, min(n, l_max)+1):
        for m in range(-l, l+1):
            ax = fig.add_subplot(n_max, n_max, (n-1)*n_max+l+1, projection='3d')
            r = np.linspace(0, 40, 200)
            theta = np.linspace(0, np.pi, 100)
            phi = np.linspace(0, 2*np.pi, 200)
            R, THETA, PHI = np.meshgrid(r, theta, phi)
            X = R * np.sin(THETA) * np.cos(PHI)
            Y = R * np.sin(THETA) * np.sin(PHI)
            Z = np.zeros((len(r), len(theta)))
            for i in range(len(r)):
                for j in range(len(theta)):
                    Z[i, j] = hydrogen_wavefunction(n, l, m, R[i, j], THETA[i, j], PHI[i, j]).real
            ax.set_title(f'n={n}, l={l}, m={m}')
            ax.plot_surface(X, Y, Z, cmap='jet', rstride=1, cstride=1, linewidth=1)
            ax.set_axis_off()

plt.show()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 84

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.special import sph_harm, genlaguerre
import matplotlib.cm as cm

def hydrogen_wavefunction(n, l, m, r, theta, phi):
    R_nl = np.sqrt((2/(n*a))**3 * np.math.factorial(n-l-1)/(2*n*np.math.factorial(n+l)**3)) * np.exp(-r/(n*a)) * (2*r/(n*a))**l * genlaguerre(n-l-1, 2*l+1)(2*r/(n*a))
    Y_lm = sph_harm(m, l, phi, theta)
    return R_nl * Y_lm

a = 1  # Bohr radius
n_max = 4  # maximum principal quantum number to plot
l_max = n_max - 1  # maximum angular momentum quantum number to plot

fig = plt.figure(figsize=(12, 12))
for n in range(1, n_max+1):
    for l in range(0, min(n, l_max)+1):
        for m in range(-l, l+1):
            ax = fig.add_subplot(n_max, n_max, (n-1)*n_max+l+1, projection='3d')
            r = np.linspace(0, 40, 200)
            theta = np.linspace(0, np.pi, 100)
            phi = np.linspace(0, 2*np.pi, 200)
            R, THETA, PHI = np.meshgrid(r, theta, phi)
            X = R * np.sin(THETA) * np.cos(PHI)
            Y = R * np.sin(THETA) * np.sin(PHI)
            Z = R * np.cos(THETA)
            WAVEFUNCTION = hydrogen_wavefunction(n, l, m, R, THETA, PHI).real  # only use the real part of the wavefunction
            ax.set_title(f'n={n}, l={l}, m={m}')
            ax.plot_surface(X, Y, Z, cmap='jet', rstride=1, cstride=1, facecolors=cm.jet(WAVEFUNCTION/WAVEFUNCTION.max()))
            ax.set_axis_off()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 17>()
#      28             WAVEFUNCTION = hydrogen_wavefunction(n, l, m, R, THETA, PHI).real  # only use the real part of the wavefunction
#      29             ax.set_title(f'n={n}, l={l}, m={m}')
# ---> 30             ax.plot_surface(X, Y, Z, cmap='jet', rstride=1, cstride=1, facecolors=cm.jet(WAVEFUNCTION/WAVEFUNCTION.max()))
#      31             ax.set_axis_off()
#      33 plt.show()
#
# File ~\Documents\WPy64-39100\python-3.9.10.amd64\lib\site-packages\matplotlib\_api\deprecation.py:431, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     421     deprecation_addendum = (
#     422         f"If any parameter follows {name!r}, they should be passed as "
#     423         f"keyword, not positionally.")
#     424     warn_deprecated(
#     425         since,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.special import sph_harm, genlaguerre
import matplotlib.cm as cm

def hydrogen_wavefunction(n, l, m, r, theta, phi):
    R_nl = np.sqrt((2/(n*a))**3 * np.math.factorial(n-l-1)/(2*n*np.math.factorial(n+l)**3)) * np.exp(-r/(n*a)) * (2*r/(n*a))**l * genlaguerre(n-l-1, 2*l+1)(2*r/(n*a))
    Y_lm = sph_harm(m, l, phi, theta)
    return R_nl * Y_lm

a = 1  # Bohr radius
n_max = 4  # maximum principal quantum number to plot
l_max = n_max - 1  # maximum angular momentum quantum number to plot

fig = plt.figure(figsize=(12, 12))
for n in range(1, n_max+1):
    for l in range(0, min(n, l_max)+1):
        for m in range(-l, l+1):
            ax = fig.add_subplot(n_max, n_max, (n-1)*n_max+l+1, projection='3d')
            r = np.linspace(0, 40, 200)
            theta = np.linspace(0, np.pi, 100)
            phi = np.linspace(0, 2*np.pi, 200)
            R, THETA, PHI = np.meshgrid(r, theta, phi)
            X = R * np.sin(THETA) * np.cos(PHI)
            Y = R * np.sin(THETA) * np.sin(PHI)
            Z = R * np.cos(THETA)
            WAVEFUNCTION = hydrogen_wavefunction(n, l, m, R, THETA, PHI)
            ax.set_title(f'n={n}, l={l}, m={m}')
            ax.plot_surface(X, Y, Z, cmap='jet', rstride=1, cstride=1, facecolors=cm.jet(WAVEFUNCTION/WAVEFUNCTION.max()))
            ax.set_axis_off()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 17>()
#      28             WAVEFUNCTION = hydrogen_wavefunction(n, l, m, R, THETA, PHI)
#      29             ax.set_title(f'n={n}, l={l}, m={m}')
# ---> 30             ax.plot_surface(X, Y, Z, cmap='jet', rstride=1, cstride=1, facecolors=cm.jet(WAVEFUNCTION/WAVEFUNCTION.max()))
#      31             ax.set_axis_off()
#      33 plt.show()
#
# File ~\Documents\WPy64-39100\python-3.9.10.amd64\lib\site-packages\matplotlib\colors.py:641, in Colormap.__call__(self, X, alpha, bytes)
#     638     lut = self._lut.copy()  # Don't let alpha modify original _lut.
#     640 rgba = np.empty(shape=xa.shape + (4,), dtype=lut.dtype)
# --> 641 lut.take(xa, axis=0, mode='clip', out=rgba)
#     643 if alpha is not None:
#     644     if np.iterable(alpha):
#
# ...

# %%
a = 1  # Bohr radius
n_max = 4  # maximum principal quantum number to plot
l_max = n_max - 1  # maximum angular momentum quantum number to plot

fig = plt.figure(figsize=(12, 12))
for n in range(1, n_max+1):
    for l in range(0, min(n, l_max)+1):
        for m in range(-l, l+1):
            ax = fig.add_subplot(n_max, n_max, (n-1)*n_max+l+1, projection='3d')
            r = np.linspace(0, 40, 200)
            theta = np.linspace(0, np.pi, 100)
            phi = np.linspace(0, 2*np.pi, 200)
            R, THETA, PHI = np.meshgrid(r, theta, phi)
            X = R * np.sin(THETA) * np.cos(PHI)
            Y = R * np.sin(THETA) * np.sin(PHI)
            Z = R * np.cos(THETA)
            WAVEFUNCTION = hydrogen_wavefunction(n, l, m, R, THETA, PHI)
            ax.set_title(f'n={n}, l={l}, m={m}')
            ax.plot_surface(X, Y, Z, cmap='jet', rstride=1, cstride=1)
            ax.set_axis_off()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 6>()
#      17             WAVEFUNCTION = hydrogen_wavefunction(n, l, m, R, THETA, PHI)
#      18             ax.set_title(f'n={n}, l={l}, m={m}')
# ---> 19             ax.plot_surface(X, Y, Z, cmap='jet', rstride=1, cstride=1)
#      20             ax.set_axis_off()
#      22 plt.show()
#
# File ~\Documents\WPy64-39100\python-3.9.10.amd64\lib\site-packages\matplotlib\_api\deprecation.py:431, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     421     deprecation_addendum = (
#     422         f"If any parameter follows {name!r}, they should be passed as "
#     423         f"keyword, not positionally.")
#     424     warn_deprecated(
#     425         since,
#     426         name=repr(name),
#    (...)
#     429                  else deprecation_addendum,
# ...
